# %%
import pandas as pd
import numpy as np

# %%
df_191 = pd.read_csv("Data/2019/JC-201901-citibike-tripdata.csv")
df_192 = pd.read_csv("Data/2019/JC-201902-citibike-tripdata.csv")
df_193 = pd.read_csv("Data/2019/JC-201903-citibike-tripdata.csv")
df_194 = pd.read_csv("Data/2019/JC-201904-citibike-tripdata.csv")
df_195 = pd.read_csv("Data/2019/JC-201905-citibike-tripdata.csv")
df_196 = pd.read_csv("Data/2019/JC-201906-citibike-tripdata.csv")

# %%
df_201 = pd.read_csv("Data/2020/JC-202001-citibike-tripdata.csv")
df_202 = pd.read_csv("Data/2020/JC-202002-citibike-tripdata.csv")
df_203 = pd.read_csv("Data/2020/JC-202003-citibike-tripdata.csv")
df_204 = pd.read_csv("Data/2020/JC-202004-citibike-tripdata.csv")
df_205 = pd.read_csv("Data/2020/JC-202005-citibike-tripdata.csv")
df_206 = pd.read_csv("Data/2020/JC-202006-citibike-tripdata.csv")

# %%
df_211 = pd.read_csv("Data/2021/JC-202101-citibike-tripdata.csv")
df_212 = pd.read_csv("Data/2021/JC-202102-citibike-tripdata.csv")
df_213 = pd.read_csv("Data/2021/JC-202103-citibike-tripdata.csv")
df_214 = pd.read_csv("Data/2021/JC-202104-citibike-tripdata.csv")
df_215 = pd.read_csv("Data/2021/JC-202105-citibike-tripdata.csv")
df_216 = pd.read_csv("Data/2021/JC-202106-citibike-tripdata.csv")

# %%
df_191.columns.tolist()
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
df_206.columns.tolist()
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
df_211.columns.tolist()
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
df_212.columns.tolist()
# Out:
# ['starttime',
#  'stoptime',
#  'start station name',
#  'start station id',
#  'end station name',
#  'end station id',
#  'start station latitude',
#  'start station longitude',
#  'end station latitude',
#  'end station longitude',
#  'usertype']

# %%
df_191.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
df_201.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
df_211.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
df_212.dtypes
# Out:
# starttime                   object
# stoptime                    object
# start station name          object
# start station id            object
# end station name            object
# end station id              object
# start station latitude     float64
# start station longitude    float64
# end station latitude       float64
# end station longitude      float64
# usertype                    object
# dtype: object

# %%
df_191.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
df_211.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1          1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2          1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3           793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4           596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
#
#    start station id start station name  start station latitude  \
# 0              3273       Manila & 1st               40.721651
# 1              3681           Grand St               40.715178
# 2              3681           Grand St               40.715178
# 3              3185          City Hall               40.717733
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.042884            3209     Brunswick St
# ...

# %%
df_212.head()
# Out:
#        starttime       stoptime          start station name start station id  \
# 0   2/3/21 23:11   2/3/21 23:18  Hoboken Ave at Monmouth St            JC105
# 1  2/27/21 16:34  2/27/21 16:56                Newport Pkwy            JC008
# 2  2/26/21 23:16  2/26/21 23:22              Journal Square            JC103
# 3  2/24/21 16:51  2/24/21 17:16  Hoboken Ave at Monmouth St            JC105
# 4  2/24/21 20:44  2/24/21 20:44  Hoboken Ave at Monmouth St            JC105
#
#              end station name end station id  start station latitude  \
# 0             Christ Hospital          JC034               40.735208
# 1            Marin Light Rail          JC013               40.728744
# 2       Baldwin at Montgomery          JC020               40.733670
# 3  Hoboken Ave at Monmouth St          JC105               40.735208
# 4  Hoboken Ave at Monmouth St          JC105               40.735208
#
#    start station longitude  end station latitude  end station longitude  \
# ...

# %%
df_2019 = pd.concat([df_191, df_192, df_193, df_194, df_195, df_196], ignore_index=True, sort=False)

# %%
df_2019
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1                505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2                756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3               1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4               1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...              ...                       ...                       ...
# 170463           639  2019-06-30 23:38:29.5450  2019-06-30 23:49:09.2110
# 170464           643  2019-06-30 23:38:34.9100  2019-06-30 23:49:17.9690
# 170465           418  2019-06-30 23:42:30.9400  2019-06-30 23:49:29.5360
# 170466          2529  2019-06-30 23:46:17.5700  2019-07-01 00:28:27.1710
# 170467           831  2019-06-30 23:49:01.6830  2019-07-01 00:02:53.1150
#
#         start station id start station name  start station latitude  \
# ...

# %%
df_2019.to_csv("Data/2019.csv", index=False)

# %%
startstation_total = df_2019["start station id"].nunique()
startstation_total
# Out:
# 52

# %%
endstation_total = df_2019["end station id"].nunique()
endstation_total
# Out:
# 85

# %%
startname_total = df_2019["start station name"].nunique()
startname_total
# Out:
# 52

# %%
endname_total = df_2019["end station name"].nunique()
endname_total
# Out:
# 85

# %%
startstations = df_2019.groupby("start station name")
startstations = startstations.mean()["tripduration"]
startstations
# Out:
# start station name
# 5 Corners Library              723.179196
# Astor Place                    932.212968
# Baldwin at Montgomery          767.586909
# Bergen Ave                     596.303597
# Brunswick & 6th                474.334525
# Brunswick St                   420.623765
# Christ Hospital                632.570568
# City Hall                      683.298094
# Columbus Drive                 509.800450
# Communipaw & Berry Lane       1817.294891
# Dey St                         697.547431
# Dixon Mills                    401.247583
# Essex Light Rail               715.402622
# Exchange Place                 721.646305
# Fairmount Ave                  510.938920
# Glenwood Ave                  1057.878484
# Grand St                       683.146278
# Grove St PATH                  447.323105
# Hamilton Park                  513.788088
# Harborside                     778.451424
# Heights Elevator              1265.258065
# Hilltop                        772.296134
# ...
